# %%
import pandas as pd

# %%
dados = pd.read_csv("dados.csv")
dados
# Out:
#           id  category/id                                         \
# 0       39.0         16.0       Meio Ambiente e Mudança do Clima
# 1       40.0         18.0                               Mulheres
# 2       49.0         27.0                                  Saúde
# 3       56.0          8.0                               Educação
# 4       60.0         36.0                      Segurança Pública
# ...      ...          ...                                    ...
# 3247  2720.0          NaN       Meio Ambiente e Mudança do Clima
# 3248  2717.0          NaN                               Educação
# 3249  2723.0          NaN                                 Saúde
# 3250  2722.0          NaN                                 Saúde
# 3251  2721.0          NaN  Integração e Desenvolvimento Regional
#
#                         Ministério                 Categoria 01  \
# 0                         Educação           Ensino Fundamental
# ...

# %%
dados = pd.DataFrame(dados, columns=['Ministério', 'Categoria 01', 'title/pt-BR','body/pt-BR'])
dados
# Out:
#                         Ministério                 Categoria 01  \
# 0                         Educação           Ensino Fundamental
# 1     Direitos Humanos e Cidadania                     Educação
# 2                            Saúde                         SUS
# 3                         Educação          Servidores Públicos
# 4      Justiça e Segurança Pública  Ampliação de Infraestrutura
# ...                            ...                          ...
# 3247                           NaN                          NaN
# 3248                      Educação                          NaN
# 3249                         Saúde                          NaN
# 3250                         Saúde                          NaN
# 3251                           NaN                          NaN
#
#                                             title/pt-BR  \
# 0                                   Educação Ambiental
# 1                          Pelo bem viver das mulheres
# ...

# %%
dados = dados.dropna()
dados
# Out:
#                         Ministério                 Categoria 01  \
# 0                         Educação           Ensino Fundamental
# 1     Direitos Humanos e Cidadania                     Educação
# 2                            Saúde                         SUS
# 3                         Educação          Servidores Públicos
# 4      Justiça e Segurança Pública  Ampliação de Infraestrutura
# ...                            ...                          ...
# 2717                      Adicione
# 2721                      Adicione            Segurança Pública
# 2723                      Educação                     Educação
# 2724                      Adicione                      Cidades
# 2798            Trabalho e Emprego                     Trabalho
#
#                                             title/pt-BR  \
# 0                                   Educação Ambiental
# 1                          Pelo bem viver das mulheres
# 2                            Proposta de programa n.01
# ...

# %%
dados.to_csv('saida.csv', index=False)
