# %% [markdown]
# # Versão 2 dos testes realizados para o modelo

# %%
import pandas as pd
import os, re, io
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import LogisticRegression

# %%
# Lê as propostas com o Pandas
propostas = pd.read_csv("production/data_extraction/propostas.csv")

propostas  # Impressão do DataFrame de propostas
# Out:
#                                            Categoria  \
# 0                                            Turismo
# 1     Desenvolvimento Agrário e Agricultura Familiar
# 2                             Agricultura e Pecuária
# 3                                              Saúde
# 4                                              Saúde
# ...                                              ...
# 8431                                           Saúde
# 8432    Secretaria Geral da Presidência da República
# 8433                              Previdência Social
# 8434                Meio Ambiente e Mudança do Clima
# 8435                                           Saúde
#
#                                                   Texto
# 0     Turismo: esse é o Destino. <p><strong>Objetivo...
# 1     Agricultura Familiar e Agroecologia. <p><stron...
# 2     Agropecuária Sustentável. <p>Objetivo: Contrib...
# 3     Atenção Primária à Saúde. <p>Fortalecer a Aten...
# 4     Atenção Especializada à Saúde. <p>Ampliar o ac...
# ...                                                 ...
# 8431  Microchipagem de animais de companhia. Microch...
# 8432   Direito a atendimento eficiente, é um direito...
# 8433  Rever Reforma da Previdência. Rever a reforma ...
# 8434  Preservação da Serra do Espinhaço. A Serra do ...
# 8435  Piso salarial pra todos.. Pra nós todos ter o ...
#
# [8436 rows x 2 columns]

# %%
# Expressões regulares para remoção de poluição de dados nos textos 
# REGX_URL = r"https?://[A-Za-z0-9./\-]+" # Regex for URLs
REGX_HTML = r"<[^<]+?>" # Regex for HTML tags
REGX_ENDING = r'Órgão Responsável:.+' # Regex for the part of the text

# %%
# Função para pré-processamento
def preprocessing(text):
  # text = text.lower()

  text = re.sub(REGX_HTML, '', text)  # Removendo tags HTML
  # text = re.sub(REGX_URL, '', text) # Revomendo URLs
  text = re.sub(REGX_ENDING, '', text)

  # tokens = [t.lemma_ for t in nlp(text) if t not in STOP_WORDS and not t.is_punct]

  return text

#  Ajustando textos da coluna Corpo
propostas['Texto'] = propostas['Texto'].apply(preprocessing)
propostas.head()
# Out:
#                                         Categoria  \
# 0                                         Turismo
# 1  Desenvolvimento Agrário e Agricultura Familiar
# 2                          Agricultura e Pecuária
# 3                                           Saúde
# 4                                           Saúde
#
#                                                Texto
# 0  Turismo: esse é o Destino. Objetivo: Posiciona...
# 1  Agricultura Familiar e Agroecologia. Objetivo:...
# 2  Agropecuária Sustentável. Objetivo: Contribuir...
# 3  Atenção Primária à Saúde. Fortalecer a Atenção...
# 4  Atenção Especializada à Saúde. Ampliar o acess...

# %%
from sklearn.model_selection import train_test_split

treino, teste, classe_treino, classe_teste = train_test_split(propostas.Texto,
                                                              propostas.Categoria,
                                                              random_state = 42)

# %%
treino
# Out:
# 3889    Hospital veterinário pelo Sus nas cidades e es...
# 838     Educação com qualidade.. Salas de aulas com me...
# 8365    Direito na escola . Criação da disciplina de d...
# 5060    Sugestão para Instrução Normativa. Instituto B...
# 6310    Tornar obrigatório o seguro automotivo . Em pa...
#                               ...
# 5734    Empreendedorismo, inovação e propriedade intel...
# 5191    Mudar a forma de trabalho de conclusão de curs...
# 5390    Banco de Projetos de Produção para Pequeno Pro...
# 860     Realizar a Conferência Nacional da Gestão e In...
# 7270    Loas e bpc sem renda precpta. Nasce uma crianç...
# Name: Texto, Length: 6327, dtype: object

# %%
classe_treino
# Out:
# 3889                     Meio Ambiente e Mudança do Clima
# 838                                              Educação
# 8365                                             Educação
# 5060               Gestão e Inovação em Serviços Públicos
# 6310         Secretaria Geral da Presidência da República
#                               ...
# 5734                       Ciência, Tecnologia e Inovação
# 5191                                             Educação
# 5390       Desenvolvimento Agrário e Agricultura Familiar
# 860                Gestão e Inovação em Serviços Públicos
# 7270    Desenvolvimento e Assistência Social, Família ...
# Name: Categoria, Length: 6327, dtype: object

# %%
print(propostas.Categoria.value_counts())
# Out:
# Categoria
# Saúde                                                             1368
# Educação                                                          1261
# Direitos Humanos e Cidadania                                       528
# Meio Ambiente e Mudança do Clima                                   497
# Transportes                                                        473
# Desenvolvimento e Assistência Social, Família e Combate à Fome     418
# Trabalho e Emprego                                                 377
# Justiça e Segurança Pública                                        342
# Cidades                                                            294
# Gestão e Inovação em Serviços Públicos                             284
# Desenvolvimento Agrário e Agricultura Familiar                     255
# Previdência Social                                                 249
# Cultura                                                            224
# Mulheres                                                           187
# Ciência, Tecnologia e Inovação                                     158
# Fazenda                                                            132
# Planejamento e Orçamento                                           125
# Turismo                                                            122
# Desenvolvimento, Indústria, Comércio e Serviços                    116
# Integração e Desenvolvimento Regional                              110
# Agricultura e Pecuária                                             103
# Minas e Energia                                                     99
# Secretaria Geral da Presidência da República                        92
# Igualdade Racial                                                    92
# Esporte                                                             90
# Defesa                                                              60
# Comunicações                                                        47
# Comunicação Social                                                  43
# Casa Civil                                                          37
# Relações Institucionais                                             37
# Povos Indígenas                                                     36
# Controladoria-Geral da União                                        30
# Pesca e Aquicultura                                                 30
# Outros                                                              27
# Segurança Institucional                                             25
# Banco Central                                                       22
# Portos e Aeroportos                                                 21
# Advocacia-Geral da União                                            13
# Relações Exteriores                                                 12
# Name: count, dtype: int64

# %%
propostas['Texto'][0]
# Out:
# 'Turismo: esse é o Destino. Objetivo: Posicionar o turismo como vetor de desenvolvimento sustentável e aumentar a competitividade dos destinos e produtos turísticos brasileiros, democratizando o acesso à atividade turística aos cidadãos brasileiros.'

# %%
#Criando índices para as categorias
cats = propostas['Categoria'].unique() # Pegando cada categoria única
cats = dict(enumerate(cats, 0)) # Convertendo para dict (com índices enumerados)
cats = {v:k for k,v in cats.items()}  # Trocando chaves e valores

propostas['id_cats'] = propostas['Categoria'].map(cats) # Inserindo coluna de índices das cats
propostas.head()
# Out:
#                                         Categoria  \
# 0                                         Turismo
# 1  Desenvolvimento Agrário e Agricultura Familiar
# 2                          Agricultura e Pecuária
# 3                                           Saúde
# 4                                           Saúde
#
#                                                Texto  id_cats
# 0  Turismo: esse é o Destino. Objetivo: Posiciona...        0
# 1  Agricultura Familiar e Agroecologia. Objetivo:...        1
# 2  Agropecuária Sustentável. Objetivo: Contribuir...        2
# 3  Atenção Primária à Saúde. Fortalecer a Atenção...        3
# 4  Atenção Especializada à Saúde. Ampliar o acess...        3

# %%
regressao_logistica = LogisticRegression(solver = "lbfgs",max_iter=1000)

def classificar_texto(texto, coluna_texto, coluna_classificacao):
    vetorizar = CountVectorizer(lowercase=False, max_features=50)
    bag_of_words = vetorizar.fit_transform(texto[coluna_texto])
    treino, teste, classe_treino, classe_teste = train_test_split(bag_of_words,
                                                              texto[coluna_classificacao],
                                                              random_state = 42)
    regressao_logistica.fit(treino, classe_treino)
    return regressao_logistica.score(teste, classe_teste)

acuracia_bruta = classificar_texto(propostas, "Texto", "id_cats")

print(acuracia_bruta)
# Out:
# 0.267425320056899

# %%
# %matplotlib inline
from wordcloud import WordCloud
import matplotlib.pyplot as plt

todas_palavras = ' '.join([texto for texto in propostas.Texto])

# %%
import nltk
from nltk import tokenize

# realiza a tokenização do texto
token_espaco = tokenize.WhitespaceTokenizer()
token_frase = token_espaco.tokenize(todas_palavras)

frequencia = nltk.FreqDist(token_frase)
df_frequencia = pd.DataFrame({"Palavra": list(frequencia.keys()),
                                   "Frequência": list(frequencia.values())})

# %%
# imprime um data frame com as palavras ordenadas pelas q tem a maior frequencia
df_frequencia.nlargest(columns = "Frequência", n = 10)
# Out:
#     Palavra  Frequência
# 10       de       30598
# 13        e       20884
# 15        a       13139
# 49     para       10234
# 66       do        8548
# 3         o        8537
# 515     que        8240
# 51       da        7868
# 36       em        5927
# 43      com        5817

# %%
import seaborn as sns

def pareto(texto, coluna_texto, quantidade):
    todas_palavras = ' '.join([texto for texto in texto[coluna_texto]])
    token_frase = token_espaco.tokenize(todas_palavras)
    frequencia = nltk.FreqDist(token_frase)
    df_frequencia = pd.DataFrame({"Palavra": list(frequencia.keys()),
                                   "Frequência": list(frequencia.values())})
    df_frequencia = df_frequencia.nlargest(columns = "Frequência", n = quantidade)
    plt.figure(figsize=(12,8))
    ax = sns.barplot(data = df_frequencia, x = "Palavra", y = "Frequência", color = 'gray')
    ax.set(ylabel = "Contagem")
    plt.show()

pareto(propostas, "Texto", 10)

# %%
palavras_irrelevantes = nltk.corpus.stopwords.words("portuguese")

frase_processada = list()
for opiniao in propostas.Texto:
    nova_frase = list()
    palavras_texto = token_espaco.tokenize(opiniao)
    for palavra in palavras_texto:
        if palavra not in palavras_irrelevantes:
            nova_frase.append(palavra)
    frase_processada.append(' '.join(nova_frase))

propostas["tratamento_1"] = frase_processada

# %%
propostas.head()
# Out:
#                                         Categoria  \
# 0                                         Turismo
# 1  Desenvolvimento Agrário e Agricultura Familiar
# 2                          Agricultura e Pecuária
# 3                                           Saúde
# 4                                           Saúde
#
#                                                Texto  id_cats  \
# 0  Turismo: esse é o Destino. Objetivo: Posiciona...        0
# 1  Agricultura Familiar e Agroecologia. Objetivo:...        1
# 2  Agropecuária Sustentável. Objetivo: Contribuir...        2
# 3  Atenção Primária à Saúde. Fortalecer a Atenção...        3
# 4  Atenção Especializada à Saúde. Ampliar o acess...        3
#
#                                         tratamento_1
# 0  Turismo: Destino. Objetivo: Posicionar turismo...
# 1  Agricultura Familiar Agroecologia. Objetivo: F...
# 2  Agropecuária Sustentável. Objetivo: Contribuir...
# 3  Atenção Primária Saúde. Fortalecer Atenção Pri...
# 4  Atenção Especializada Saúde. Ampliar acesso aç...

# %%
acuracia_tratamento_1 = classificar_texto(propostas, "tratamento_1", "id_cats")
print(acuracia_tratamento_1)
# Out:
# 0.3399715504978663

# %%
pareto(propostas,"tratamento_1", 10)

# %%
from string import punctuation

token_pontuacao = tokenize.WordPunctTokenizer()

pontuacao = list()
for ponto in punctuation:
    pontuacao.append(ponto)

pontuacao_stopwords = pontuacao + palavras_irrelevantes

frase_processada = list()
for opiniao in propostas["tratamento_1"]:
    nova_frase = list()
    palavras_texto = token_pontuacao.tokenize(opiniao)
    for palavra in palavras_texto:
        if palavra not in pontuacao_stopwords:
            nova_frase.append(palavra)
    frase_processada.append(' '.join(nova_frase))

propostas["tratamento_2"] = frase_processada

# %%
propostas.head()
# Out:
#                                         Categoria  \
# 0                                         Turismo
# 1  Desenvolvimento Agrário e Agricultura Familiar
# 2                          Agricultura e Pecuária
# 3                                           Saúde
# 4                                           Saúde
#
#                                                Texto  id_cats  \
# 0  Turismo: esse é o Destino. Objetivo: Posiciona...        0
# 1  Agricultura Familiar e Agroecologia. Objetivo:...        1
# 2  Agropecuária Sustentável. Objetivo: Contribuir...        2
# 3  Atenção Primária à Saúde. Fortalecer a Atenção...        3
# 4  Atenção Especializada à Saúde. Ampliar o acess...        3
#
#                                         tratamento_1  \
# 0  Turismo: Destino. Objetivo: Posicionar turismo...
# 1  Agricultura Familiar Agroecologia. Objetivo: F...
# 2  Agropecuária Sustentável. Objetivo: Contribuir...
# 3  Atenção Primária Saúde. Fortalecer Atenção Pri...
# 4  Atenção Especializada Saúde. Ampliar acesso aç...
#
#                                         tratamento_2
# 0  Turismo Destino Objetivo Posicionar turismo ve...
# 1  Agricultura Familiar Agroecologia Objetivo For...
# 2  Agropecuária Sustentável Objetivo Contribuir d...
# 3  Atenção Primária Saúde Fortalecer Atenção Prim...
# 4  Atenção Especializada Saúde Ampliar acesso açõ...

# %%
acuracia_tratamento2 = classificar_texto(propostas, "tratamento_2", "id_cats")
print(acuracia_tratamento2)
# Out:
# 0.3409198672356567

# %%
propostas["tratamento_1"][0]
# Out:
# 'Turismo: Destino. Objetivo: Posicionar turismo vetor desenvolvimento sustentável aumentar competitividade destinos produtos turísticos brasileiros, democratizando acesso atividade turística cidadãos brasileiros.'

# %%
propostas["tratamento_2"][0]
# Out:
# 'Turismo Destino Objetivo Posicionar turismo vetor desenvolvimento sustentável aumentar competitividade destinos produtos turísticos brasileiros democratizando acesso atividade turística cidadãos brasileiros'

# %%
pareto(propostas,"tratamento_2", 10)

# %%
import unidecode 

sem_acentos = [unidecode.unidecode(texto) for texto in propostas["tratamento_2"]]

# %%
sem_acentos[0]
# Out:
# 'Turismo Destino Objetivo Posicionar turismo vetor desenvolvimento sustentavel aumentar competitividade destinos produtos turisticos brasileiros democratizando acesso atividade turistica cidadaos brasileiros'

# %%
stopwords_sem_acento = [unidecode.unidecode(texto) for texto in pontuacao_stopwords]

# %%
stopwords_sem_acento
# Out:
# ['!',
#  '"',
#  '#',
#  '$',
#  '%',
#  '&',
#  "'",
#  '(',
#  ')',
#  '*',
#  '+',
#  ',',
#  '-',
#  '.',
#  '/',
#  ':',
#  ';',
#  '<',
#  '=',
#  '>',
#  '?',
#  '@',
#  '[',
#  '\\',
#  ']',
#  '^',
#  '_',
#  '`',
#  '{',
#  '|',
#  '}',
#  '~',
#  'a',
#  'a',
#  'ao',
#  'aos',
#  'aquela',
#  'aquelas',
#  'aquele',
#  'aqueles',
#  'aquilo',
#  'as',
#  'as',
#  'ate',
#  'com',
#  'como',
#  'da',
#  'das',
#  'de',
#  'dela',
#  'delas',
#  'dele',
#  'deles',
#  'depois',
#  'do',
#  'dos',
#  'e',
#  'e',
#  'ela',
#  'elas',
#  'ele',
#  'eles',
#  'em',
#  'entre',
#  'era',
#  'eram',
#  'eramos',
#  'essa',
#  'essas',
#  'esse',
#  'esses',
#  'esta',
#  'esta',
#  'estamos',
#  'estao',
#  'estar',
#  'estas',
#  'estava',
#  'estavam',
#  'estavamos',
#  'este',
#  'esteja',
#  'estejam',
#  'estejamos',
#  'estes',
#  'esteve',
#  'estive',
#  'estivemos',
#  'estiver',
#  'estivera',
#  'estiveram',
#  'estiveramos',
#  'estiverem',
#  'estivermos',
#  'estivesse',
#  'estivessem',
#  'estivessemos',
#  'estou',
#  'eu',
#  'foi',
#  'fomos',
#  'for',
#  'fora',
#  'foram',
#  'foramos',
#  'forem',
#  'formos',
#  'fosse',
#  'fossem',
#  'fossemos',
#  'fui',
#  'ha',
#  'haja',
#  'hajam',
#  'hajamos',
#  'hao',
#  'havemos',
#  'haver',
#  'hei',
#  'houve',
#  'houvemos',
#  'houver',
#  'houvera',
#  'houvera',
#  'houveram',
#  'houveramos',
#  'houverao',
#  'houverei',
#  'houverem',
#  'houveremos',
#  'houveria',
#  'houveriam',
#  'houveriamos',
#  'houvermos',
#  'houvesse',
#  'houvessem',
#  'houvessemos',
#  'isso',
#  'isto',
#  'ja',
#  'lhe',
#  'lhes',
#  'mais',
#  'mas',
#  'me',
#  'mesmo',
#  'meu',
#  'meus',
#  'minha',
#  'minhas',
#  'muito',
#  'na',
#  'nao',
#  'nas',
#  'nem',
#  'no',
#  'nos',
#  'nos',
#  'nossa',
#  'nossas',
#  'nosso',
#  'nossos',
#  'num',
#  'numa',
#  'o',
#  'os',
#  'ou',
#  'para',
#  'pela',
#  'pelas',
#  'pelo',
#  'pelos',
#  'por',
#  'qual',
#  'quando',
#  'que',
#  'quem',
#  'sao',
#  'se',
#  'seja',
#  'sejam',
#  'sejamos',
#  'sem',
#  'ser',
#  'sera',
#  'serao',
#  'serei',
#  'seremos',
#  'seria',
#  'seriam',
#  'seriamos',
#  'seu',
#  'seus',
#  'so',
#  'somos',
#  'sou',
#  'sua',
#  'suas',
#  'tambem',
#  'te',
#  'tem',
#  'tem',
#  'temos',
#  'tenha',
#  'tenham',
#  'tenhamos',
#  'tenho',
#  'tera',
#  'terao',
#  'terei',
#  'teremos',
#  'teria',
#  'teriam',
#  'teriamos',
#  'teu',
#  'teus',
#  'teve',
#  'tinha',
#  'tinham',
#  'tinhamos',
#  'tive',
#  'tivemos',
#  'tiver',
#  'tivera',
#  'tiveram',
#  'tiveramos',
#  'tiverem',
#  'tivermos',
#  'tivesse',
#  'tivessem',
#  'tivessemos',
#  'tu',
#  'tua',
#  'tuas',
#  'um',
#  'uma',
#  'voce',
#  'voces',
#  'vos']

# %%
propostas["tratamento_3"] = sem_acentos

frase_processada = list()
for opiniao in propostas["tratamento_3"]:
    nova_frase = list()
    palavras_texto = token_pontuacao.tokenize(opiniao)
    for palavra in palavras_texto:
        if palavra not in pontuacao_stopwords:
            nova_frase.append(palavra)
    frase_processada.append(' '.join(nova_frase))

propostas["tratamento_3"] = frase_processada

# %%
propostas.head()
# Out:
#                                         Categoria  \
# 0                                         Turismo
# 1  Desenvolvimento Agrário e Agricultura Familiar
# 2                          Agricultura e Pecuária
# 3                                           Saúde
# 4                                           Saúde
#
#                                                Texto  id_cats  \
# 0  Turismo: esse é o Destino. Objetivo: Posiciona...        0
# 1  Agricultura Familiar e Agroecologia. Objetivo:...        1
# 2  Agropecuária Sustentável. Objetivo: Contribuir...        2
# 3  Atenção Primária à Saúde. Fortalecer a Atenção...        3
# 4  Atenção Especializada à Saúde. Ampliar o acess...        3
#
#                                         tratamento_1  \
# 0  Turismo: Destino. Objetivo: Posicionar turismo...
# 1  Agricultura Familiar Agroecologia. Objetivo: F...
# 2  Agropecuária Sustentável. Objetivo: Contribuir...
# 3  Atenção Primária Saúde. Fortalecer Atenção Pri...
# 4  Atenção Especializada Saúde. Ampliar acesso aç...
#
#                                         tratamento_2  \
# 0  Turismo Destino Objetivo Posicionar turismo ve...
# 1  Agricultura Familiar Agroecologia Objetivo For...
# 2  Agropecuária Sustentável Objetivo Contribuir d...
# 3  Atenção Primária Saúde Fortalecer Atenção Prim...
# 4  Atenção Especializada Saúde Ampliar acesso açõ...
#
#                                         tratamento_3
# 0  Turismo Destino Objetivo Posicionar turismo ve...
# 1  Agricultura Familiar Agroecologia Objetivo For...
# 2  Agropecuaria Sustentavel Objetivo Contribuir d...
# 3  Atencao Primaria Saude Fortalecer Atencao Prim...
# 4  Atencao Especializada Saude Ampliar acesso aco...

# %%
acuracia_tratamento3 = classificar_texto(propostas, "tratamento_3", "id_cats")
print(acuracia_tratamento3)
# Out:
# 0.3432906590801328

# %%
#deixa todas as letras minusculas
frase_processada = list()
for opiniao in propostas["tratamento_3"]:
    nova_frase = list()
    opiniao = opiniao.lower()
    palavras_texto = token_pontuacao.tokenize(opiniao)
    for palavra in palavras_texto:
        if palavra not in stopwords_sem_acento:
            nova_frase.append(palavra)
    frase_processada.append(' '.join(nova_frase))

propostas["tratamento_4"] = frase_processada

# %%
propostas["tratamento_3"][0]
# Out:
# 'Turismo Destino Objetivo Posicionar turismo vetor desenvolvimento sustentavel aumentar competitividade destinos produtos turisticos brasileiros democratizando acesso atividade turistica cidadaos brasileiros'

# %%
propostas["tratamento_4"][0]
# Out:
# 'turismo destino objetivo posicionar turismo vetor desenvolvimento sustentavel aumentar competitividade destinos produtos turisticos brasileiros democratizando acesso atividade turistica cidadaos brasileiros'

# %%
acuracia_tratamento4 = classificar_texto(propostas, "tratamento_4", "id_cats")
print(acuracia_tratamento4)
# Out:
# 0.3703176861071598

# %%
pareto(propostas, "tratamento_4", 10)

# %% [markdown]
# # Teste com a Stemização

# %%
nltk.download('rslp')
# faz a stemetizacao
stemmer = nltk.RSLPStemmer()
# Out:
# [nltk_data] Downloading package rslp to /home/anacleto/nltk_data...
# [nltk_data]   Package rslp is already up-to-date!

# %%
frase_processada = list()
for opiniao in propostas["tratamento_4"]:
    nova_frase = list()
    palavras_texto = token_pontuacao.tokenize(opiniao)
    for palavra in palavras_texto:
        if palavra not in stopwords_sem_acento:
            nova_frase.append(stemmer.stem(palavra))
    frase_processada.append(' '.join(nova_frase))

propostas["tratamento_5"] = frase_processada

# %%
acuracia_tratamento5 = classificar_texto(propostas, "tratamento_5", "id_cats")
print(acuracia_tratamento5)
# Out:
# 0.3845424371740161

# %%
pareto(propostas, "tratamento_5", 10)

# %% [markdown]
# # Testando a utilização do TF-IDF no dataframe

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer(lowercase=False, max_features=50)

tfidf_tratados = tfidf.fit_transform(propostas["tratamento_5"])
treino, teste, classe_treino, classe_teste = train_test_split(tfidf_tratados,
                                                              propostas["id_cats"],
                                                              random_state = 42)
regressao_logistica.fit(treino, classe_treino)
acuracia_tfidf_tratados = regressao_logistica.score(teste, classe_teste)

print(acuracia_tfidf_tratados)
# Out:
# 0.3878615457562826

# %% [markdown]
# # Testando a utilizacao do TF-IDF juntamente com o ngrams

# %%
from nltk import ngrams

#acuracia do tfidf utilizando os ngrams
tfidf = TfidfVectorizer(lowercase=False, ngram_range = (1,2))
vetor_tfidf = tfidf.fit_transform(propostas["tratamento_5"])
treino, teste, classe_treino, classe_teste = train_test_split(vetor_tfidf,
                                                              propostas["id_cats"],
                                                              random_state = 42)
regressao_logistica.fit(treino, classe_treino)
acuracia_tfidf_ngrams = regressao_logistica.score(teste, classe_teste)
print(acuracia_tfidf_ngrams)
# Out:
# 0.5462304409672831

# %%
#palavras que o modelo aprendeu da categoria saude (id_cats 3)
pesos = pd.DataFrame(
    regressao_logistica.coef_[3].T,
    index = tfidf.get_feature_names_out()
)

pesos.nlargest(50,0)
# Out:
#                      0
# saud          9.159293
# su            5.623140
# enferm        4.474794
# medic         4.232534
# atend         3.622046
# hospit        3.583248
# doenc         3.470541
# paci          3.436454
# pis           3.142520
# trat          2.662821
# atenca        2.475173
# profiss       2.229910
# dent          2.224310
# ac            2.125600
# exam          2.116578
# ment          1.861211
# salar         1.737057
# pis salar     1.664521
# hor           1.626270
# equip         1.617407
# agent         1.601179
# cirurg        1.583633
# este          1.492555
# insalubr      1.487767
# odontolog     1.440544
# diagnost      1.399626
# fibromialg    1.321636
# cuid          1.306053
# categor       1.283845
# canc          1.262074
# especi        1.237478
# terap         1.188942
# farmaceu      1.176957
# medicin       1.174852
# saud publ     1.161170
# psicolog      1.161142
# estetic       1.147735
# upa           1.122256
# clin          1.121023
# reabilitaca   1.107370
# saud ment     1.101956
# farmac        1.086221
# socorr        1.083101
# aut           1.071618
# sang          1.050775
# carg hor      1.049607
# ub            1.042084
# profiss saud  1.011047
# centr         1.009879
# populaca      1.005349

# %%
import matplotlib.pyplot as plt

# Dados numéricos
dados = [acuracia_bruta * 100, acuracia_tratamento_1 * 100, acuracia_tratamento2 * 100,
         acuracia_tratamento3 * 100, acuracia_tratamento4 * 100, acuracia_tratamento5 * 100,
         acuracia_tfidf_ngrams * 100]
etiquetas = ['bruta', '1', '2', '3', '4', '5', 'stem ngram']

# Criar o gráfico de barras
plt.bar(etiquetas, dados, color='blue')

# Adicionar título e rótulos dos eixos
plt.title('Acuracia tratamentos')
plt.xlabel('Tratamentos')
plt.ylabel('Acuracia')

# Adicionar os valores acima de cada barra
for i, valor in enumerate(dados):
    plt.text(i, valor + 1, f'{valor:.2f}%', ha='center')

# Exibir o gráfico
plt.show()

# %% [markdown]
# # Testando com o SVM utilizando o tratamento 4 ou seja sem a stemizacao

# %%
propostas.head()
# Out:
#                                         Categoria  \
# 0                                         Turismo
# 1  Desenvolvimento Agrário e Agricultura Familiar
# 2                          Agricultura e Pecuária
# 3                                           Saúde
# 4                                           Saúde
#
#                                                Texto  id_cats  \
# 0  Turismo: esse é o Destino. Objetivo: Posiciona...        0
# 1  Agricultura Familiar e Agroecologia. Objetivo:...        1
# 2  Agropecuária Sustentável. Objetivo: Contribuir...        2
# 3  Atenção Primária à Saúde. Fortalecer a Atenção...        3
# 4  Atenção Especializada à Saúde. Ampliar o acess...        3
#
#                                         tratamento_1  \
# 0  Turismo: Destino. Objetivo: Posicionar turismo...
# 1  Agricultura Familiar Agroecologia. Objetivo: F...
# 2  Agropecuária Sustentável. Objetivo: Contribuir...
# 3  Atenção Primária Saúde. Fortalecer Atenção Pri...
# 4  Atenção Especializada Saúde. Ampliar acesso aç...
#
#                                         tratamento_2  \
# 0  Turismo Destino Objetivo Posicionar turismo ve...
# 1  Agricultura Familiar Agroecologia Objetivo For...
# 2  Agropecuária Sustentável Objetivo Contribuir d...
# 3  Atenção Primária Saúde Fortalecer Atenção Prim...
# 4  Atenção Especializada Saúde Ampliar acesso açõ...
#
#                                         tratamento_3  \
# 0  Turismo Destino Objetivo Posicionar turismo ve...
# 1  Agricultura Familiar Agroecologia Objetivo For...
# 2  Agropecuaria Sustentavel Objetivo Contribuir d...
# 3  Atencao Primaria Saude Fortalecer Atencao Prim...
# 4  Atencao Especializada Saude Ampliar acesso aco...
#
#                                         tratamento_4  \
# 0  turismo destino objetivo posicionar turismo ve...
# 1  agricultura familiar agroecologia objetivo for...
# 2  agropecuaria sustentavel objetivo contribuir d...
# 3  atencao primaria saude fortalecer atencao prim...
# 4  atencao especializada saude ampliar acesso aco...
#
#                                         tratamento_5
# 0  tur destin obje posic tur vet desenvolv susten...
# 1  agricult famili agroecolog obje fortalec agric...
# 2  agropecu sustenta obje contribu desenvolv set ...
# 3  atenca prim saud fortalec atenca prim saud amp...
# 4  atenca especi saud ampli acess aco serv atenca...

# %%
import spacy
from spacy.lang.pt.stop_words import STOP_WORDS

nlp = spacy.load("pt_core_news_sm")

# %%
#  Representações vetoriais do texto
propostas['Vector'] = propostas['tratamento_4'].apply(lambda text: nlp(text).vector)
propostas.head()
# Out:
#                                         Categoria  \
# 0                                         Turismo
# 1  Desenvolvimento Agrário e Agricultura Familiar
# 2                          Agricultura e Pecuária
# 3                                           Saúde
# 4                                           Saúde
#
#                                                Texto  id_cats  \
# 0  Turismo: esse é o Destino. Objetivo: Posiciona...        0
# 1  Agricultura Familiar e Agroecologia. Objetivo:...        1
# 2  Agropecuária Sustentável. Objetivo: Contribuir...        2
# 3  Atenção Primária à Saúde. Fortalecer a Atenção...        3
# 4  Atenção Especializada à Saúde. Ampliar o acess...        3
#
#                                         tratamento_1  \
# 0  Turismo: Destino. Objetivo: Posicionar turismo...
# 1  Agricultura Familiar Agroecologia. Objetivo: F...
# 2  Agropecuária Sustentável. Objetivo: Contribuir...
# 3  Atenção Primária Saúde. Fortalecer Atenção Pri...
# 4  Atenção Especializada Saúde. Ampliar acesso aç...
#
#                                         tratamento_2  \
# 0  Turismo Destino Objetivo Posicionar turismo ve...
# 1  Agricultura Familiar Agroecologia Objetivo For...
# 2  Agropecuária Sustentável Objetivo Contribuir d...
# 3  Atenção Primária Saúde Fortalecer Atenção Prim...
# 4  Atenção Especializada Saúde Ampliar acesso açõ...
#
#                                         tratamento_3  \
# 0  Turismo Destino Objetivo Posicionar turismo ve...
# 1  Agricultura Familiar Agroecologia Objetivo For...
# 2  Agropecuaria Sustentavel Objetivo Contribuir d...
# 3  Atencao Primaria Saude Fortalecer Atencao Prim...
# 4  Atencao Especializada Saude Ampliar acesso aco...
#
#                                         tratamento_4  \
# 0  turismo destino objetivo posicionar turismo ve...
# 1  agricultura familiar agroecologia objetivo for...
# 2  agropecuaria sustentavel objetivo contribuir d...
# 3  atencao primaria saude fortalecer atencao prim...
# 4  atencao especializada saude ampliar acesso aco...
#
#                                         tratamento_5  \
# 0  tur destin obje posic tur vet desenvolv susten...
# 1  agricult famili agroecolog obje fortalec agric...
# 2  agropecu sustenta obje contribu desenvolv set ...
# 3  atenca prim saud fortalec atenca prim saud amp...
# 4  atenca especi saud ampli acess aco serv atenca...
#
#                                               Vector
# 0  [0.5342785, -0.022150597, -1.2641029, 1.000174...
# 1  [-1.2358813, 1.6805387, -1.0609051, 1.7490908,...
# 2  [-0.8280421, 0.2889977, -1.0518178, 0.757612, ...
# 3  [-1.656974, 0.9785773, -0.17303433, 2.8001845,...
# 4  [0.14726144, 0.8421648, 0.023294607, 1.8071848...

# %%
from sklearn.metrics import accuracy_score, classification_report
from sklearn.preprocessing import MinMaxScaler
from sklearn import svm, model_selection
import numpy as np

# %%
# Separação dos dados para treinamento e teste
treino, teste, classe_treino, classe_teste = model_selection.train_test_split(
    propostas.Vector.values,
    propostas.Categoria,
    test_size=0.2
)

# Transformação: conversão do tipo dos dados de entrada (X) para interpretação
treino_2d = np.stack(treino)
teste_2d = np.stack(teste)

# Transformação: escalonamento dos dados numéricos (normalizados entre 0 e 1)
# Para tratamento de casos outliers
scaler = MinMaxScaler()
scaled_train_embed = scaler.fit_transform(treino_2d)
scaled_test_embed = scaler.transform(teste_2d)

# %%
import json

# Treinamento
clf = svm.SVC() # Instanciando modelo
clf.fit(scaled_train_embed, classe_treino)  # Realização do treinamento passando os dados

classe_pred = clf.predict(scaled_test_embed) # Predição com os dados de teste

# Salvando relatório de treinamento em um arquivo JSON
json_obj = json.dumps(classification_report(classe_teste, classe_pred, output_dict=True), indent=4)
save_file = open('model/teste_results.json', 'w').write(json_obj)

# Impressão do relatório com as métricas do modelo (para cada cat.)
print(classification_report(classe_teste, classe_pred))  

predictions_SVM = clf.predict(scaled_test_embed)
print("SVM Accuracy Score -> ", accuracy_score(predictions_SVM, classe_teste)*100)  # Impressão da precisão geral
# Out:
# /home/anacleto/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/anacleto/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/anacleto/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/anacleto/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/anacleto/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/anacleto/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#                                                                 precision    recall  f1-score   support
#
#                                         Agricultura e Pecuária       0.00      0.00      0.00        21
#                                                  Banco Central       0.00      0.00      0.00         4
#                                                     Casa Civil       0.00      0.00      0.00         6
#                                                        Cidades       0.00      0.00      0.00        67
#                                 Ciência, Tecnologia e Inovação       0.00      0.00      0.00        41
#                                             Comunicação Social       0.00      0.00      0.00         5
#                                                   Comunicações       0.00      0.00      0.00         9
#                                   Controladoria-Geral da União       0.00      0.00      0.00         8
#                                                        Cultura       1.00      0.04      0.07        54
#                                                         Defesa       0.00      0.00      0.00        17
#                 Desenvolvimento Agrário e Agricultura Familiar       0.50      0.06      0.11        48
# Desenvolvimento e Assistência Social, Família e Combate à Fome       0.15      0.03      0.04        76
#                Desenvolvimento, Indústria, Comércio e Serviços       0.00      0.00      0.00        16
#                                   Direitos Humanos e Cidadania       0.09      0.06      0.07        89
#                                                       Educação       0.27      0.76      0.40       251
#                                                        Esporte       0.00      0.00      0.00        18
#                                                        Fazenda       0.00      0.00      0.00        29
#                         Gestão e Inovação em Serviços Públicos       0.50      0.02      0.04        53
#                                               Igualdade Racial       0.00      0.00      0.00        20
#                          Integração e Desenvolvimento Regional       0.00      0.00      0.00        25
#                                    Justiça e Segurança Pública       0.86      0.19      0.31        63
#                               Meio Ambiente e Mudança do Clima       0.20      0.19      0.19        97
#                                                Minas e Energia       0.00      0.00      0.00        18
#                                                       Mulheres       0.38      0.11      0.17        27
#                                                         Outros       0.00      0.00      0.00         7
#                                            Pesca e Aquicultura       0.00      0.00      0.00         5
#                                       Planejamento e Orçamento       0.00      0.00      0.00        25
#                                            Portos e Aeroportos       0.00      0.00      0.00         5
#                                                Povos Indígenas       0.00      0.00      0.00         5
#                                             Previdência Social       0.67      0.04      0.07        51
#                                            Relações Exteriores       0.00      0.00      0.00         3
#                                        Relações Institucionais       0.00      0.00      0.00         9
#                                                          Saúde       0.30      0.77      0.43       277
#                   Secretaria Geral da Presidência da República       0.00      0.00      0.00        19
#                                        Segurança Institucional       0.00      0.00      0.00         6
#                                             Trabalho e Emprego       0.62      0.08      0.15        97
#                                                    Transportes       0.38      0.26      0.31        90
#                                                        Turismo       0.00      0.00      0.00        27
#
#                                                       accuracy                           0.29      1688
#                                                      macro avg       0.16      0.07      0.06      1688
#                                                   weighted avg       0.29      0.29      0.19      1688
#
# SVM Accuracy Score ->  28.613744075829384

# %% [markdown]
# # Teste da regressao logistica com a lematizacao usando o spacy

# %%
propostas.head()
# Out:
#                                         Categoria  \
# 0                                         Turismo
# 1  Desenvolvimento Agrário e Agricultura Familiar
# 2                          Agricultura e Pecuária
# 3                                           Saúde
# 4                                           Saúde
#
#                                                Texto  id_cats  \
# 0  Turismo: esse é o Destino. Objetivo: Posiciona...        0
# 1  Agricultura Familiar e Agroecologia. Objetivo:...        1
# 2  Agropecuária Sustentável. Objetivo: Contribuir...        2
# 3  Atenção Primária à Saúde. Fortalecer a Atenção...        3
# 4  Atenção Especializada à Saúde. Ampliar o acess...        3
#
#                                         tratamento_1  \
# 0  Turismo: Destino. Objetivo: Posicionar turismo...
# 1  Agricultura Familiar Agroecologia. Objetivo: F...
# 2  Agropecuária Sustentável. Objetivo: Contribuir...
# 3  Atenção Primária Saúde. Fortalecer Atenção Pri...
# 4  Atenção Especializada Saúde. Ampliar acesso aç...
#
#                                         tratamento_2  \
# 0  Turismo Destino Objetivo Posicionar turismo ve...
# 1  Agricultura Familiar Agroecologia Objetivo For...
# 2  Agropecuária Sustentável Objetivo Contribuir d...
# 3  Atenção Primária Saúde Fortalecer Atenção Prim...
# 4  Atenção Especializada Saúde Ampliar acesso açõ...
#
#                                         tratamento_3  \
# 0  Turismo Destino Objetivo Posicionar turismo ve...
# 1  Agricultura Familiar Agroecologia Objetivo For...
# 2  Agropecuaria Sustentavel Objetivo Contribuir d...
# 3  Atencao Primaria Saude Fortalecer Atencao Prim...
# 4  Atencao Especializada Saude Ampliar acesso aco...
#
#                                         tratamento_4  \
# 0  turismo destino objetivo posicionar turismo ve...
# 1  agricultura familiar agroecologia objetivo for...
# 2  agropecuaria sustentavel objetivo contribuir d...
# 3  atencao primaria saude fortalecer atencao prim...
# 4  atencao especializada saude ampliar acesso aco...
#
#                                         tratamento_5  \
# 0  tur destin obje posic tur vet desenvolv susten...
# 1  agricult famili agroecolog obje fortalec agric...
# 2  agropecu sustenta obje contribu desenvolv set ...
# 3  atenca prim saud fortalec atenca prim saud amp...
# 4  atenca especi saud ampli acess aco serv atenca...
#
#                                               Vector
# 0  [0.5342785, -0.022150597, -1.2641029, 1.000174...
# 1  [-1.2358813, 1.6805387, -1.0609051, 1.7490908,...
# 2  [-0.8280421, 0.2889977, -1.0518178, 0.757612, ...
# 3  [-1.656974, 0.9785773, -0.17303433, 2.8001845,...
# 4  [0.14726144, 0.8421648, 0.023294607, 1.8071848...

# %%
frase_processada = list()
for opiniao in propostas["tratamento_4"]:
    nova_frase = list()
    doc = nlp(opiniao)
    for token in doc:
        nova_frase.append(token.lemma_)
    frase_processada.append(' '.join(nova_frase))

propostas["tratamento_6"] = frase_processada

# %%
propostas.head()
# Out:
#                                         Categoria  \
# 0                                         Turismo
# 1  Desenvolvimento Agrário e Agricultura Familiar
# 2                          Agricultura e Pecuária
# 3                                           Saúde
# 4                                           Saúde
#
#                                                Texto  id_cats  \
# 0  Turismo: esse é o Destino. Objetivo: Posiciona...        0
# 1  Agricultura Familiar e Agroecologia. Objetivo:...        1
# 2  Agropecuária Sustentável. Objetivo: Contribuir...        2
# 3  Atenção Primária à Saúde. Fortalecer a Atenção...        3
# 4  Atenção Especializada à Saúde. Ampliar o acess...        3
#
#                                         tratamento_1  \
# 0  Turismo: Destino. Objetivo: Posicionar turismo...
# 1  Agricultura Familiar Agroecologia. Objetivo: F...
# 2  Agropecuária Sustentável. Objetivo: Contribuir...
# 3  Atenção Primária Saúde. Fortalecer Atenção Pri...
# 4  Atenção Especializada Saúde. Ampliar acesso aç...
#
#                                         tratamento_2  \
# 0  Turismo Destino Objetivo Posicionar turismo ve...
# 1  Agricultura Familiar Agroecologia Objetivo For...
# 2  Agropecuária Sustentável Objetivo Contribuir d...
# 3  Atenção Primária Saúde Fortalecer Atenção Prim...
# 4  Atenção Especializada Saúde Ampliar acesso açõ...
#
#                                         tratamento_3  \
# 0  Turismo Destino Objetivo Posicionar turismo ve...
# 1  Agricultura Familiar Agroecologia Objetivo For...
# 2  Agropecuaria Sustentavel Objetivo Contribuir d...
# 3  Atencao Primaria Saude Fortalecer Atencao Prim...
# 4  Atencao Especializada Saude Ampliar acesso aco...
#
#                                         tratamento_4  \
# 0  turismo destino objetivo posicionar turismo ve...
# 1  agricultura familiar agroecologia objetivo for...
# 2  agropecuaria sustentavel objetivo contribuir d...
# 3  atencao primaria saude fortalecer atencao prim...
# 4  atencao especializada saude ampliar acesso aco...
#
#                                         tratamento_5  \
# 0  tur destin obje posic tur vet desenvolv susten...
# 1  agricult famili agroecolog obje fortalec agric...
# 2  agropecu sustenta obje contribu desenvolv set ...
# 3  atenca prim saud fortalec atenca prim saud amp...
# 4  atenca especi saud ampli acess aco serv atenca...
#
#                                               Vector  \
# 0  [0.5342785, -0.022150597, -1.2641029, 1.000174...
# 1  [-1.2358813, 1.6805387, -1.0609051, 1.7490908,...
# 2  [-0.8280421, 0.2889977, -1.0518178, 0.757612, ...
# 3  [-1.656974, 0.9785773, -0.17303433, 2.8001845,...
# 4  [0.14726144, 0.8421648, 0.023294607, 1.8071848...
#
#                                         tratamento_6
# 0  Turismo destino objetivo posicionar turismo ve...
# 1  agricultura familiar agroecologia objetivo for...
# 2  agropecuar sustentavel objetivo contribuir des...
# 3  atencao primario saude fortalecer atencao prim...
# 4  atencao especializar saude ampliar acesso acoe...

# %%
from nltk import ngrams

#acuracia do tfidf utilizando os ngrams
tfidf = TfidfVectorizer(lowercase=False, ngram_range = (1,2))
vetor_tfidf = tfidf.fit_transform(propostas["tratamento_6"])
treino, teste, classe_treino, classe_teste = train_test_split(vetor_tfidf,
                                                              propostas["id_cats"],
                                                              random_state = 42)
regressao_logistica.fit(treino, classe_treino)
acuracia_lemma = regressao_logistica.score(teste, classe_teste)
print(acuracia_lemma)
# Out:
# 0.5272641062114747

# %%
import matplotlib.pyplot as plt

# Dados numéricos
dados = [acuracia_bruta * 100, acuracia_tratamento_1 * 100, acuracia_tratamento2 * 100,
         acuracia_tratamento3 * 100, acuracia_tratamento4 * 100, acuracia_tratamento5 * 100,
         acuracia_tfidf_ngrams * 100,acuracia_lemma * 100]
etiquetas = ['bruta', '1', '2', '3', '4', '5', 'stem','lemma']
 
# Criar o gráfico de barras
plt.bar(etiquetas, dados, color='blue')

# Adicionar título e rótulos dos eixos
plt.title('Acuracia tratamentos')
plt.xlabel('Tratamentos')
plt.ylabel('Acuracia')

# Adicionar os valores acima de cada barra
for i, valor in enumerate(dados):
    plt.text(i, valor + 1, f'{valor:.2f}%', ha='center')

# Exibir o gráfico
plt.show()

# %% [markdown]
# # Aplicando o TF-IDF com Ngrams nos dados sem stemizacao e lematizacao no SVC

# %%
from sklearn.svm import SVC
from sklearn.metrics import classification_report

# Dividir dados em treinamento e teste
X_train, X_test, y_train, y_test = train_test_split(propostas['tratamento_4'],propostas["Categoria"], test_size=0.2, random_state=42)

# Criar vetorizador TF-IDF com n-grams
vectorizer = TfidfVectorizer(ngram_range=(1, 2))  # Aqui usamos bigrams
X_train_tfidf = vectorizer.fit_transform(X_train)
X_test_tfidf = vectorizer.transform(X_test)

# Treinar SVM
svm_model = SVC(kernel='linear')  # Pode usar outros kernels também
svm_model.fit(X_train_tfidf, y_train)

# Prever e avaliar
y_pred = svm_model.predict(X_test_tfidf)
report = classification_report(y_test, y_pred)

print(report)
# Out:
#                                                                 precision    recall  f1-score   support
#
#                                       Advocacia-Geral da União       0.00      0.00      0.00         1
#                                         Agricultura e Pecuária       1.00      0.07      0.13        14
#                                                  Banco Central       0.00      0.00      0.00         4
#                                                     Casa Civil       0.00      0.00      0.00         4
#                                                        Cidades       0.59      0.44      0.50        55
#                                 Ciência, Tecnologia e Inovação       0.55      0.19      0.29        31
#                                             Comunicação Social       1.00      0.20      0.33         5
#                                                   Comunicações       1.00      0.10      0.18        10
#                                   Controladoria-Geral da União       0.00      0.00      0.00         9
#                                                        Cultura       0.72      0.62      0.67        50
#                                                         Defesa       0.50      0.14      0.22         7
#                 Desenvolvimento Agrário e Agricultura Familiar       0.65      0.64      0.64        55
# Desenvolvimento e Assistência Social, Família e Combate à Fome       0.44      0.37      0.40        92
#                Desenvolvimento, Indústria, Comércio e Serviços       0.67      0.09      0.15        23
#                                   Direitos Humanos e Cidadania       0.29      0.44      0.35       101
#                                                       Educação       0.67      0.84      0.74       277
#                                                        Esporte       0.80      0.57      0.67        14
#                                                        Fazenda       0.56      0.36      0.44        25
#                         Gestão e Inovação em Serviços Públicos       0.51      0.41      0.46        56
#                                               Igualdade Racial       0.50      0.25      0.33        20
#                          Integração e Desenvolvimento Regional       1.00      0.14      0.24        22
#                                    Justiça e Segurança Pública       0.68      0.64      0.66        64
#                               Meio Ambiente e Mudança do Clima       0.65      0.86      0.74       104
#                                                Minas e Energia       0.55      0.57      0.56        21
#                                                       Mulheres       0.58      0.60      0.59        35
#                                                         Outros       0.00      0.00      0.00        10
#                                            Pesca e Aquicultura       1.00      0.25      0.40         4
#                                       Planejamento e Orçamento       0.67      0.08      0.14        25
#                                            Portos e Aeroportos       0.00      0.00      0.00         4
#                                                Povos Indígenas       1.00      0.33      0.50         6
#                                             Previdência Social       0.68      0.57      0.62        46
#                                            Relações Exteriores       0.00      0.00      0.00         1
#                                        Relações Institucionais       0.00      0.00      0.00         2
#                                                          Saúde       0.66      0.83      0.74       276
#                   Secretaria Geral da Presidência da República       0.50      0.19      0.27        16
#                                        Segurança Institucional       0.00      0.00      0.00         3
#                                             Trabalho e Emprego       0.47      0.58      0.52        65
#                                                    Transportes       0.64      0.77      0.70       101
#                                                        Turismo       1.00      0.60      0.75        30
#
#                                                       accuracy                           0.60      1688
#                                                      macro avg       0.53      0.33      0.36      1688
#                                                   weighted avg       0.61      0.60      0.58      1688
# /home/anacleto/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/anacleto/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/anacleto/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Imprimir relatório com weighted avg em forma de porcentagem
print("Classification Report:")
for class_label, metrics in report.items():
    if class_label == 'weighted avg':
        weighted_avg_precision = metrics['precision'] * 100
        weighted_avg_recall = metrics['recall'] * 100
        weighted_avg_f1 = metrics['f1-score'] * 100
        weighted_avg_support = metrics['support']
        
        print(f"Weighted Avg Precision: {weighted_avg_precision:.2f}%")
        print(f"Weighted Avg Recall: {weighted_avg_recall:.2f}%")
        print(f"Weighted Avg F1-Score: {weighted_avg_f1:.2f}%")
        print(f"Weighted Avg Support: {weighted_avg_support}")
        break
# Out:
# Classification Report:
# Weighted Avg Precision: 60.85%
# Weighted Avg Recall: 60.49%
# Weighted Avg F1-Score: 57.76%
# Weighted Avg Support: 1688.0

# %% [markdown]
# # Aplicando o TF-IDF com Ngrams nos dados com lematizacao no SVC

# %%
from sklearn.svm import SVC
from sklearn.metrics import classification_report

# Dividir dados em treinamento e teste
X_train, X_test, y_train, y_test = train_test_split(propostas['tratamento_6'],propostas["Categoria"], test_size=0.2, random_state=42)

# Criar vetorizador TF-IDF com n-grams
vectorizer = TfidfVectorizer(ngram_range=(1, 2))  # Aqui usamos bigrams
X_train_tfidf = vectorizer.fit_transform(X_train)
X_test_tfidf = vectorizer.transform(X_test)

# Treinar SVM
svm_model = SVC(kernel='linear')  # Pode usar outros kernels também
svm_model.fit(X_train_tfidf, y_train)

# Prever e avaliar
y_pred = svm_model.predict(X_test_tfidf)
report = classification_report(y_test, y_pred)

print(report)
# Out:
#                                                                 precision    recall  f1-score   support
#
#                                       Advocacia-Geral da União       0.00      0.00      0.00         1
#                                         Agricultura e Pecuária       1.00      0.14      0.25        14
#                                                  Banco Central       0.00      0.00      0.00         4
#                                                     Casa Civil       0.00      0.00      0.00         4
#                                                        Cidades       0.52      0.47      0.50        55
#                                 Ciência, Tecnologia e Inovação       0.50      0.19      0.28        31
#                                             Comunicação Social       1.00      0.20      0.33         5
#                                                   Comunicações       1.00      0.20      0.33        10
#                                   Controladoria-Geral da União       0.00      0.00      0.00         9
#                                                        Cultura       0.72      0.62      0.67        50
#                                                         Defesa       0.33      0.14      0.20         7
#                 Desenvolvimento Agrário e Agricultura Familiar       0.68      0.65      0.67        55
# Desenvolvimento e Assistência Social, Família e Combate à Fome       0.51      0.41      0.46        92
#                Desenvolvimento, Indústria, Comércio e Serviços       0.33      0.09      0.14        23
#                                   Direitos Humanos e Cidadania       0.29      0.46      0.35       101
#                                                       Educação       0.68      0.83      0.75       277
#                                                        Esporte       0.69      0.64      0.67        14
#                                                        Fazenda       0.65      0.44      0.52        25
#                         Gestão e Inovação em Serviços Públicos       0.47      0.38      0.42        56
#                                               Igualdade Racial       0.60      0.30      0.40        20
#                          Integração e Desenvolvimento Regional       1.00      0.14      0.24        22
#                                    Justiça e Segurança Pública       0.72      0.64      0.68        64
#                               Meio Ambiente e Mudança do Clima       0.66      0.83      0.73       104
#                                                Minas e Energia       0.55      0.57      0.56        21
#                                                       Mulheres       0.59      0.69      0.63        35
#                                                         Outros       0.00      0.00      0.00        10
#                                            Pesca e Aquicultura       1.00      0.25      0.40         4
#                                       Planejamento e Orçamento       0.67      0.08      0.14        25
#                                            Portos e Aeroportos       0.00      0.00      0.00         4
#                                                Povos Indígenas       1.00      0.33      0.50         6
#                                             Previdência Social       0.66      0.54      0.60        46
#                                            Relações Exteriores       0.00      0.00      0.00         1
#                                        Relações Institucionais       0.00      0.00      0.00         2
#                                                          Saúde       0.68      0.81      0.74       276
#                   Secretaria Geral da Presidência da República       0.57      0.25      0.35        16
#                                        Segurança Institucional       0.00      0.00      0.00         3
#                                             Trabalho e Emprego       0.49      0.63      0.55        65
#                                                    Transportes       0.64      0.76      0.69       101
#                                                        Turismo       1.00      0.70      0.82        30
#
#                                                       accuracy                           0.61      1688
#                                                      macro avg       0.52      0.34      0.37      1688
#                                                   weighted avg       0.61      0.61      0.59      1688
# /home/anacleto/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/anacleto/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/anacleto/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# # Aplicando o TF-IDF com Ngrams nos dados com stemizacao no SVC

# %%
from sklearn.svm import SVC
from sklearn.metrics import classification_report

# Dividir dados em treinamento e teste
X_train, X_test, y_train, y_test = train_test_split(propostas['tratamento_5'],propostas["Categoria"], test_size=0.2, random_state=42)

# Criar vetorizador TF-IDF com n-grams
vectorizer = TfidfVectorizer(ngram_range=(1, 2))  # Aqui usamos bigrams
X_train_tfidf = vectorizer.fit_transform(X_train)
X_test_tfidf = vectorizer.transform(X_test)

# Treinar SVM
svm_model = SVC(kernel='linear')  # Pode usar outros kernels também
svm_model.fit(X_train_tfidf, y_train)

# Prever e avaliar
y_pred = svm_model.predict(X_test_tfidf)
report = classification_report(y_test, y_pred)

print(report)
# Out:
#                                                                 precision    recall  f1-score   support
#
#                                       Advocacia-Geral da União       0.00      0.00      0.00         1
#                                         Agricultura e Pecuária       1.00      0.14      0.25        14
#                                                  Banco Central       0.00      0.00      0.00         4
#                                                     Casa Civil       0.00      0.00      0.00         4
#                                                        Cidades       0.49      0.38      0.43        55
#                                 Ciência, Tecnologia e Inovação       0.54      0.23      0.32        31
#                                             Comunicação Social       1.00      0.20      0.33         5
#                                                   Comunicações       1.00      0.30      0.46        10
#                                   Controladoria-Geral da União       0.00      0.00      0.00         9
#                                                        Cultura       0.72      0.66      0.69        50
#                                                         Defesa       0.33      0.14      0.20         7
#                 Desenvolvimento Agrário e Agricultura Familiar       0.62      0.65      0.64        55
# Desenvolvimento e Assistência Social, Família e Combate à Fome       0.46      0.37      0.41        92
#                Desenvolvimento, Indústria, Comércio e Serviços       0.43      0.13      0.20        23
#                                   Direitos Humanos e Cidadania       0.29      0.45      0.35       101
#                                                       Educação       0.72      0.83      0.77       277
#                                                        Esporte       0.67      0.71      0.69        14
#                                                        Fazenda       0.57      0.48      0.52        25
#                         Gestão e Inovação em Serviços Públicos       0.46      0.45      0.45        56
#                                               Igualdade Racial       0.58      0.35      0.44        20
#                          Integração e Desenvolvimento Regional       1.00      0.18      0.31        22
#                                    Justiça e Segurança Pública       0.68      0.62      0.65        64
#                               Meio Ambiente e Mudança do Clima       0.64      0.80      0.71       104
#                                                Minas e Energia       0.52      0.57      0.55        21
#                                                       Mulheres       0.60      0.69      0.64        35
#                                                         Outros       0.00      0.00      0.00        10
#                                            Pesca e Aquicultura       1.00      0.50      0.67         4
#                                       Planejamento e Orçamento       0.67      0.08      0.14        25
#                                            Portos e Aeroportos       0.00      0.00      0.00         4
#                                                Povos Indígenas       0.75      0.50      0.60         6
#                                             Previdência Social       0.69      0.63      0.66        46
#                                            Relações Exteriores       0.00      0.00      0.00         1
#                                        Relações Institucionais       0.00      0.00      0.00         2
#                                                          Saúde       0.69      0.82      0.75       276
#                   Secretaria Geral da Presidência da República       0.57      0.25      0.35        16
#                                        Segurança Institucional       0.00      0.00      0.00         3
#                                             Trabalho e Emprego       0.49      0.63      0.55        65
#                                                    Transportes       0.64      0.76      0.69       101
#                                                        Turismo       1.00      0.67      0.80        30
#
#                                                       accuracy                           0.61      1688
#                                                      macro avg       0.51      0.36      0.39      1688
#                                                   weighted avg       0.61      0.61      0.59      1688
# /home/anacleto/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/anacleto/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/anacleto/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
